# %% [markdown]
# <h1>INSTALADOR STABLE DIFFUSION + MODELOS</h1>
#
# Para instalar se debe borrar el hashtag al comienzo de cada línea de código que se quiera instalar.
#
# 1. Stable Diffusion WebUI
# 2. Modelos SD
# 3. Modelos ControlNet v1.1
# 4. Modelos LoRa

# %% [markdown]
# <h2>1. Stable Diffusion WebUi</h2>

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# Out:
# fatal: destination path 'stable-diffusion-webui' already exists and is not an empty directory.

# %% [markdown]
# <h2>2. Instalador de VAE</h2>

# %%
# %cd /notebooks/stable-diffusion-webui/models/VAE
# !wget https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors

# %% [markdown]
# <h2>2. Descargador de modelos</h2>
# Para descargar un modelo se debe eliminar el hashtag al comienzo de la línea de código antes del !wget. Una vez instalado el modelo, volver a agregar el hashtag.

# %%
#%cd /notebooks/stable-diffusion-webui/models/Stable-diffusion

"""ReV Animated 1.2.2"""
#!wget https://huggingface.co/s6yx/ReV_Animated/resolve/main/rev_1.2.2/rev_1.2.2.safetensors
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/rev_1.2.2.safetensors

"""DreamShaper 5 Beta 2 Baked VAE (7 Gb)"""
#!wget https://huggingface.co/Lykon/DreamShaper/resolve/main/DreamShaper_5_beta2_BakedVae.ckpt
""" PARA ELIMINARLO """
#!rm -r /notebooks/stable-diffusion-webui/models/Stable-diffusion/DreamShaper_5_beta2_BakedVae.ckpt

"""Deliberate V2"""
#!wget https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v2.safetensors
""" PARA ELIMINARLO """
#!rm -r /notebooks/stable-diffusion-webui/models/Stable-diffusion/Deliberate_v2.safetensors

"""Dreamlike Diffusion tags: dreamlikeart"""
#!wget https://huggingface.co/dreamlike-art/dreamlike-diffusion-1.0/resolve/main/dreamlike-diffusion-1.0.ckpt
""" PARA ELIMINARLO """
#!rm -r /notebooks/stable-diffusion-webui/models/Stable-diffusion/dreamlike-diffusion-1.0.ckpt

"""InkPunk Diffusion v2 tags: nvinkpunk"""
#!wget https://huggingface.co/Envvi/Inkpunk-Diffusion/resolve/main/Inkpunk-Diffusion-v2.ckpt
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/Inkpunk-Diffusion-v2.ckpt

"""Analog Diffusion v1 tags: analog style / negative prompts: blur haze naked"""
#!wget https://huggingface.co/wavymulder/Analog-Diffusion/resolve/main/analog-diffusion-1.0.ckpt
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/analog-diffusion-1.0.ckpt

"""Ghibli Diffusion tags: ghibli style"""
#!wget https://huggingface.co/nitrosocke/Ghibli-Diffusion/resolve/main/ghibli-diffusion-v1.ckpt
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/ghibli-diffusion-v1.ckpt

"""Paper Cut Model tags: PaperCut"""
#!wget https://huggingface.co/Fictiverse/Stable_Diffusion_PaperCut_Model/resolve/main/PaperCut_v1.safetensors
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/PaperCut_v1.safetensors

"""Double exposure diffusion v2 tags: dublex style or just dublex"""
#!wget https://huggingface.co/joachimsallstrom/Double-Exposure-Diffusion/resolve/main/Double_Exposure_v2.safetensors
""" PARA ELIMINARLO """
#!rm -r /notebooks/stable-diffusion-webui/models/Stable-diffusion/Double_Exposure_v2.safetensors

"""Reliberate v1.0"""
#!wget https://huggingface.co/XpucT/Reliberate/resolve/main/Reliberate.safetensors
""" PARA ELIMINARLO """
#!rm /notebooks/stable-diffusion-webui/models/Stable-diffusion/Reliberate.safetensors
# Out:
# rm: cannot remove '/notebooks/stable-diffusion-webui/models/Stable-diffusion/DreamShaper_5_beta2_BakedVae.ckpt': No such file or directory
# rm: cannot remove '/notebooks/stable-diffusion-webui/models/Stable-diffusion/Deliberate_v2.safetensors': No such file or directory
# rm: cannot remove '/notebooks/stable-diffusion-webui/models/Stable-diffusion/dreamlike-diffusion-1.0.ckpt': No such file or directory
# rm: cannot remove '/notebooks/stable-diffusion-webui/models/Stable-diffusion/Double_Exposure_v2.safetensors': No such file or directory
# ' PARA ELIMINARLO '

# %% [markdown]
# <h2>3. Modelos ControlNet v1.1</h2>
# Debe estar instalada la extensión

# %%
#%cd /notebooks/stable-diffusion-webui/extensions/sd-webui-controlnet/models
#!wget -r -nd -A '*.pth,*.yaml' https://huggingface.co/lllyasviel/ControlNet-v1-1/tree/main
# Out:
# /notebooks/stable-diffusion-webui/extensions/sd-webui-controlnet/models
# --2023-07-04 05:29:42--  https://huggingface.co/lllyasviel/ControlNet-v1-1/tree/main
# Resolving huggingface.co (huggingface.co)... 18.164.124.99, 18.164.124.47, 18.164.124.27, ...
# Connecting to huggingface.co (huggingface.co)|18.164.124.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 239482 (234K) [text/html]
# Saving to: ‘main.tmp’
#
# main.tmp            100%[===================>] 233.87K  --.-KB/s    in 0.006s
#
# 2023-07-04 05:29:42 (38.7 MB/s) - ‘main.tmp’ saved [239482/239482]
#
# Loading robots.txt; please ignore errors.
# --2023-07-04 05:29:42--  https://huggingface.co/robots.txt
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23 [text/plain]
# Saving to: ‘robots.txt.tmp’
#
# robots.txt.tmp      100%[===================>]      23  --.-KB/s    in 0s
#
# ...

# %% [markdown]
# <h2>4. Modelos LoRa</h2>

# %%
# %cd /notebooks/stable-diffusion-webui/models/Lora
# Out:
# /notebooks/stable-diffusion-webui/models/Lora
